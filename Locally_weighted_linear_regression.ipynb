# %% [markdown]
# <a href="https://colab.research.google.com/github/Rashmihashok7299/ML-Lab/blob/master/Locally_weighted_linear_regression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt

x = np.linspace(-5, 0, 1000)
y = np.log(np.abs((x ** 2) - 1) + 0.5)
x = x + np.random.normal(scale=0.05, size=1000)
plt.scatter(x, y, alpha=0.3)


def local_regression(x0, x, y, tau):
    x0 = np.r_[1, x0]
    x = np.c_[np.ones(len(x)), x]
    xw = x.T * radial_kernel(x0, x, tau)
    beta = np.linalg.pinv(xw @ x) @ xw @ y
    return x0 @ beta


def radial_kernel(x0, x, tau):
    return np.exp(np.sum((x - x0) ** 2, axis=1) / (-2 * tau ** 2))


def plot_lr(tau):
    domain = np.linspace(2, 5, num=300)
    pred = [local_regression(x0, x, y, tau) for x0 in domain]
    plt.scatter(x, y, alpha=0.3)
    plt.plot(domain, pred, color="red")
    return plt


plot_lr(0.1).show()
plot_lr(0.5).show()
plot_lr(0.9).show()
plot_lr(1.9).show()
plot_lr(2.9).show()
plot_lr(3.9).show()
plot_lr(4.9).show()
# Out:
# /usr/local/lib/python3.6/dist-packages/numpy/linalg/linalg.py:1966: RuntimeWarning: overflow encountered in true_divide
#   s = divide(1, s, where=large, out=s)
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:14: RuntimeWarning: invalid value encountered in matmul
#
# /usr/local/lib/python3.6/dist-packages/numpy/linalg/linalg.py:1969: RuntimeWarning: invalid value encountered in matmul
#   res = matmul(transpose(vt), multiply(s[..., newaxis], transpose(u)))
# /usr/local/lib/python3.6/dist-packages/numpy/linalg/linalg.py:1969: RuntimeWarning: invalid value encountered in multiply
#   res = matmul(transpose(vt), multiply(s[..., newaxis], transpose(u)))
