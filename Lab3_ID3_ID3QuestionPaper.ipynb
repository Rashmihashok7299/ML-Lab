# %% [markdown]
# <a href="https://colab.research.google.com/github/Rashmihashok7299/ML-Lab/blob/master/Lab3_ID3_ID3QuestionPaper.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# # DECISION TREE IMPLEMENTATION- ENTROPY AND INFO GAIN

import pandas as pd 

df_tennis = pd.read_csv(r"/content/id3dataset.csv")

def entropy(probs): 
    import math 
    return sum( [-prob*math.log(prob, 2) for prob in probs] )

def entropy_of_list(a_list): 
    from collections import Counter     
    cnt = Counter(x for x in a_list) 
    print("No and Yes Classes:",a_list.name,cnt)     
    num_instances = len(a_list)*1.0     
    probs = [x / num_instances for x in cnt.values()]     
    return entropy(probs) # Call Entropy:

total_entropy = entropy_of_list(df_tennis['Classification']) 
print("Entropy of given Data Set:",total_entropy) 


# In[11]:


def information_gain(df, split_attribute_name, target_attribute_name, trace=0): 
    print("&&&&&&&&&")
    for name,group in df_split:         
        print(name)         
        print(group) 


# In[13]:


def information_gain(df, split_attribute_name, target_attribute_name, trace=0): 
    df_split = df.groupby(split_attribute_name)
    print("splitttttttttttttttttttt")
    print(split_attribute_name)
    print("******************")
    for name,group in df_split:         
        print("Name:",name)
        print("Group:",group)
    print("$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$")
    nobs = len(df.index) * 1.0
    df_agg_ent = df_split.agg({target_attribute_name : [entropy_of_list, lambda x: len(x)/nobs] })[target_attribute_name] 
    df_agg_ent.columns = ['Entropy', 'PropObservations'] 
    new_entropy = sum(df_agg_ent['Entropy'] * df_agg_ent['PropObservations'] )
    old_entropy = entropy_of_list(df[target_attribute_name]) 
    return old_entropy - new_entropy


# In[18]:


print('Info-gain for A1 is :'+str( information_gain(df_tennis, 'A1', 'Classification')),"\n") 
print('\n Info-gain for A2 is: ' + str( information_gain(df_tennis, 'A2', 'Classification')),"\n") 
print('\n Info-gain for A3 is:' + str( information_gain(df_tennis, 'A3', 'Classification')),"\n")


# In[21]:


def id3(df, target_attribute_name, attribute_names, default_class=None):
    from collections import Counter     
    cnt = Counter(x for x in df[target_attribute_name])
    if len(cnt) == 1:         
        return next(iter(cnt)) 
    elif df.empty or (not attribute_names): 
             return default_class 
    else:
        gainz = [information_gain(df, attr, target_attribute_name) for attr in attribute_names]
        print("ATTRIBUTE NAME:",attribute_names)
        index_of_max = gainz.index(max(gainz)) 
        best_attr = attribute_names[index_of_max] 
        tree = {best_attr:{}}
        remaining_attribute_names = [i for i in attribute_names if i != best_attr]
        for attr_val, data_subset in df.groupby(best_attr): 
            subtree = id3(data_subset,
                          target_attribute_name,                         
                          remaining_attribute_names,                         
                          default_class)
            tree[best_attr][attr_val] = subtree 
        return tree
     
        


# In[22]:


attribute_names = list(df_tennis.columns)
print("List of Attributes:", attribute_names) 
attribute_names.remove('Classification') 
print("Predicting Attributes:", attribute_names)


# In[23]:


from pprint import pprint 
tree = id3(df_tennis,'Classification',attribute_names)
print("\n\nThe Resultant Decision Tree is :\n") 
pprint(tree)
# Out:
# No and Yes Classes: Classification Counter({'No': 5, 'Yes': 5})
# Entropy of given Data Set: 1.0
# splitttttttttttttttttttt
# A1
# ******************
# Name: False
# Group:       A1    A2      A3 Classification
# 2  False   Hot    High            Yes
# 3  False  Cool  Normal            Yes
# 4  False  Cool  Normal            Yes
# 8  False  Cool  Normal            Yes
# 9  False  Cool    High             No
# Name: True
# Group:      A1    A2      A3 Classification
# 0  True   Hot    High             No
# 1  True   Hot    High             No
# 5  True  Cool    High             No
# 6  True   Hot    High             No
# 7  True   Hot  Normal            Yes
# $$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$
# No and Yes Classes: Classification Counter({'Yes': 4, 'No': 1})
# No and Yes Classes: Classification Counter({'No': 4, 'Yes': 1})
# No and Yes Classes: Classification Counter({'No': 5, 'Yes': 5})
# Info-gain for A1 is :0.2780719051126377
#
# splitttttttttttttttttttt
# A2
# ******************
# Name: Cool
# Group:       A1    A2      A3 Classification
# 3  False  Cool  Normal            Yes
# 4  False  Cool  Normal            Yes
# 5   True  Cool    High             No
# 8  False  Cool  Normal            Yes
# 9  False  Cool    High             No
# Name: Hot
# Group:       A1   A2      A3 Classification
# 0   True  Hot    High             No
# 1   True  Hot    High             No
# 2  False  Hot    High            Yes
# 6   True  Hot    High             No
# 7   True  Hot  Normal            Yes
# $$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$
# No and Yes Classes: Classification Counter({'Yes': 3, 'No': 2})
# No and Yes Classes: Classification Counter({'No': 3, 'Yes': 2})
# No and Yes Classes: Classification Counter({'No': 5, 'Yes': 5})
#
#  Info-gain for A2 is: 0.02904940554533142
#
# splitttttttttttttttttttt
# A3
# ******************
# Name: High
# Group:       A1    A2    A3 Classification
# 0   True   Hot  High             No
# 1   True   Hot  High             No
# 2  False   Hot  High            Yes
# 5   True  Cool  High             No
# 6   True   Hot  High             No
# 9  False  Cool  High             No
# Name: Normal
# Group:       A1    A2      A3 Classification
# 3  False  Cool  Normal            Yes
# 4  False  Cool  Normal            Yes
# 7   True   Hot  Normal            Yes
# 8  False  Cool  Normal            Yes
# $$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$
# No and Yes Classes: Classification Counter({'No': 5, 'Yes': 1})
# No and Yes Classes: Classification Counter({'Yes': 4})
# No and Yes Classes: Classification Counter({'No': 5, 'Yes': 5})
#
#  Info-gain for A3 is:0.6099865470109875
#
# List of Attributes: ['A1', 'A2', 'A3', 'Classification']
# Predicting Attributes: ['A1', 'A2', 'A3']
# splitttttttttttttttttttt
# A1
# ******************
# Name: False
# Group:       A1    A2      A3 Classification
# 2  False   Hot    High            Yes
# 3  False  Cool  Normal            Yes
# 4  False  Cool  Normal            Yes
# 8  False  Cool  Normal            Yes
# 9  False  Cool    High             No
# Name: True
# Group:      A1    A2      A3 Classification
# 0  True   Hot    High             No
# 1  True   Hot    High             No
# 5  True  Cool    High             No
# 6  True   Hot    High             No
# 7  True   Hot  Normal            Yes
# $$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$
# No and Yes Classes: Classification Counter({'Yes': 4, 'No': 1})
# No and Yes Classes: Classification Counter({'No': 4, 'Yes': 1})
# No and Yes Classes: Classification Counter({'No': 5, 'Yes': 5})
# splitttttttttttttttttttt
# A2
# ******************
# Name: Cool
# Group:       A1    A2      A3 Classification
# 3  False  Cool  Normal            Yes
# 4  False  Cool  Normal            Yes
# 5   True  Cool    High             No
# 8  False  Cool  Normal            Yes
# 9  False  Cool    High             No
# Name: Hot
# Group:       A1   A2      A3 Classification
# 0   True  Hot    High             No
# 1   True  Hot    High             No
# 2  False  Hot    High            Yes
# 6   True  Hot    High             No
# 7   True  Hot  Normal            Yes
# $$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$
# No and Yes Classes: Classification Counter({'Yes': 3, 'No': 2})
# No and Yes Classes: Classification Counter({'No': 3, 'Yes': 2})
# No and Yes Classes: Classification Counter({'No': 5, 'Yes': 5})
# splitttttttttttttttttttt
# A3
# ******************
# Name: High
# Group:       A1    A2    A3 Classification
# 0   True   Hot  High             No
# 1   True   Hot  High             No
# 2  False   Hot  High            Yes
# 5   True  Cool  High             No
# 6   True   Hot  High             No
# 9  False  Cool  High             No
# Name: Normal
# Group:       A1    A2      A3 Classification
# 3  False  Cool  Normal            Yes
# 4  False  Cool  Normal            Yes
# 7   True   Hot  Normal            Yes
# 8  False  Cool  Normal            Yes
# $$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$
# No and Yes Classes: Classification Counter({'No': 5, 'Yes': 1})
# No and Yes Classes: Classification Counter({'Yes': 4})
# No and Yes Classes: Classification Counter({'No': 5, 'Yes': 5})
# ATTRIBUTE NAME: ['A1', 'A2', 'A3']
# splitttttttttttttttttttt
# A1
# ******************
# Name: False
# Group:       A1    A2    A3 Classification
# 2  False   Hot  High            Yes
# 9  False  Cool  High             No
# Name: True
# Group:      A1    A2    A3 Classification
# 0  True   Hot  High             No
# 1  True   Hot  High             No
# 5  True  Cool  High             No
# 6  True   Hot  High             No
# $$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$
# No and Yes Classes: Classification Counter({'Yes': 1, 'No': 1})
# No and Yes Classes: Classification Counter({'No': 4})
# No and Yes Classes: Classification Counter({'No': 5, 'Yes': 1})
# splitttttttttttttttttttt
# A2
# ******************
# Name: Cool
# Group:       A1    A2    A3 Classification
# 5   True  Cool  High             No
# 9  False  Cool  High             No
# Name: Hot
# Group:       A1   A2    A3 Classification
# 0   True  Hot  High             No
# 1   True  Hot  High             No
# 2  False  Hot  High            Yes
# 6   True  Hot  High             No
# $$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$
# No and Yes Classes: Classification Counter({'No': 2})
# No and Yes Classes: Classification Counter({'No': 3, 'Yes': 1})
# No and Yes Classes: Classification Counter({'No': 5, 'Yes': 1})
# ATTRIBUTE NAME: ['A1', 'A2']
# splitttttttttttttttttttt
# A2
# ******************
# Name: Cool
# Group:       A1    A2    A3 Classification
# 9  False  Cool  High             No
# Name: Hot
# Group:       A1   A2    A3 Classification
# 2  False  Hot  High            Yes
# $$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$$
# No and Yes Classes: Classification Counter({'No': 1})
# No and Yes Classes: Classification Counter({'Yes': 1})
# No and Yes Classes: Classification Counter({'Yes': 1, 'No': 1})
# ATTRIBUTE NAME: ['A2']
#
#
# The Resultant Decision Tree is :
#
# {'A3': {'High': {'A1': {False: {'A2': {'Cool': 'No', 'Hot': 'Yes'}},
#                         True: 'No'}},
#         'Normal': 'Yes'}}
